# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# url for loan_data dataset
url = ".\data-set\\arquivoKNN_normalizado.csv"

# Assign column names to the dataset
names = ['Loan ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
# Read in the dataset
df = pd.read_csv(url, names=names)

df.head()
# Out:
#    Loan ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        0     0.0        1         1.0        1.0            0.0
# 1        1     0.0        1         0.0        1.0            1.0
# 2        2     0.0        1         0.0        0.0            0.0
# 3        3     0.0        0         0.0        1.0            0.0
# 4        4     0.0        1         0.0        0.0            0.0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           4583.0             1508.0       128.0             360.0
# 1           3000.0                0.0        66.0             360.0
# 2           2583.0             2358.0       120.0             360.0
# 3           6000.0                0.0       141.0             360.0
# 4           2333.0             1516.0        95.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            0
# 1             1.0              0            1
# ...

# %%
X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8181818181818182

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Suponha que você tenha os rótulos verdadeiros e as previsões do seu modelo
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 1, 0, 0]

# Calcular precisão
precision = precision_score(y_true, y_pred)

# Calcular revocação
recall = recall_score(y_true, y_pred)

# Calcular pontuação F
f1 = f1_score(y_true, y_pred)

print("Precisão:", precision)
print("Revocação:", recall)
print("Pontuação F:", f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[319], line 8
#       4 y_true = y_train
#       5 # y_pred = [0, 1, 1, 0, 0]
#       6
#       7 # Calcular precisão
# ----> 8 precision = precision_score(y_true, y_pred)
#      10 # Calcular revocação
#      11 recall = recall_score(y_true, y_pred)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...
